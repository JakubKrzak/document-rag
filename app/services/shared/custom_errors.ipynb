# %%
#bazowe klasy

class RagBaseError(Exception):
    def __init__(self, file_name:str=None):
        super().__init__(file_name)
        self.file_name = file_name

class DocumentError(RagBaseError):
    pass

class DataBaseError(RagBaseError):
    pass

class ChunkingError(RagBaseError):
    pass

class EmbeddingError(RagBaseError):
    pass

# %%
#Wyjatki
class DocumentNotFoundError(DocumentError):
    def __init__(self, file_name:str):
        super().__init__(f"Document {file_name} not found")

class PathNotFoundError(DocumentError):
    def __init__(self, path:str):
        super().__init__(f"Path ({path}) not found")

class AddFileToDataBaseError(DataBaseError):
    def __init__(self, file_name:str):
        super().__init__(f"Failed to add info file {file_name} to database")

class ChunksEmptyError(ChunkingError):
    def __init__(self, file_name:str):
        super().__init__(f"Chunks from file {file_name} are empty")

class EmptyVectorsError(EmbeddingError):
    def __init__(self, file_name:str):
        super().__init__(f"Vectors from file {file_name} are empty")

class WrongVectorsDimError(EmbeddingError):
    def __init__(self, file_name:str, current_vector_dim:int, excepted_vector_dim:int)
        super().__init__(f"The dimensions of the vectors are wrong, current_dim={len(current_vector_dim[0])}, expected_vector_dim={excepted_vector_dim}")

# %%
e = DocumentNotFoundError("doc.txt")
raise e
# Out:
# ---------------------------------------------------------------------------
# DocumentNotFoundError                     Traceback (most recent call last)
# Cell In[47], line 2
#       1 e = DocumentNotFoundError("doc.txt")
# ----> 2 raise e
#
# DocumentNotFoundError: Document doc.txt not found

# %%
p = PathNotFoundError("~/home/kuba/projekty")
raise p
# Out:
# ---------------------------------------------------------------------------
# PathNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 p = PathNotFoundError("~/home/kuba/projekty")
# ----> 2 raise p
#
# PathNotFoundError: Path (~/home/kuba/projekty) not found

# %%
db = AddFileToDataBaseError("dokument.pdf")
raise db
# Out:
# ---------------------------------------------------------------------------
# AddFileToDataBaseError                    Traceback (most recent call last)
# Cell In[35], line 2
#       1 db = AddFileToDataBaseError("dokument.pdf")
# ----> 2 raise db
#
# AddFileToDataBaseError: Failed to add info file dokument.pdf to database

# %%
chunks_empty = ChunksEmptyError("chunki.pdf")
raise chunks_empty
# Out:
# ---------------------------------------------------------------------------
# ChunksEmptyError                          Traceback (most recent call last)
# Cell In[49], line 2
#       1 chunks_empty = ChunksEmptyError("chunki.pdf")
# ----> 2 raise chunks_empty
#
# ChunksEmptyError: Chunks from file chunki.pdf are empty
